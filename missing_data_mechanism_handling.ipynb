# %%
#6주차 
#결측치 : 데이터셋에서 특정 값이 비어있는 상황 
# NaN , None 형태로 나타남 
#MCAR : 무작위 결측치로 분석에 영향을 주지 않으므로 제거해도 무방 
#MAR (Missing At Random): 특정 변수와 관련이 있으나 분석 결과에 큰 영향을 주지 않는 경우, 대체하여 보완 가능하다.
#MNAR (Missing Not at Random) : 데이터 자체의 특성과 관련된 결측치로, 보간법을 통한 신중한 대체가 필요하다.

# %%
# 선형 보간법 : 두 점 사이를 연결해서 중간값을 채움 
import pandas as pd
import numpy as np

df = pd.DataFrame({'value': [1, np.nan, 3, np.nan, 5]})
df['value'] = df['value'].interpolate(method='linear')
print(df)
# Out:
#    value
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0

# %%
#다항식 보간법 : 곡선형 변화에 유용 
df['value'] = df['value'].interpolate(method='polynomial', order=2)
print(df)
# Out:
#    value
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0

# %%
#제곱근 보간법 
df['value'] = df['value'].interpolate(method='quadratic')
print(df)
# Out:
#    value
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0

# %%
#시간 보간법 
df.index = pd.date_range("2022-01-01", periods=5)
df['value'] = df['value'].interpolate(method='time')
print(df)
# Out:
#             value
# 2022-01-01    1.0
# 2022-01-02    2.0
# 2022-01-03    3.0
# 2022-01-04    4.0
# 2022-01-05    5.0

# %%
#앞뒤 채움법 
# 1. 이전 값으로 채움 (pad/ffill 대신 ffill() 사용)
df['value'] = df['value'].ffill()
print(df)

# 2. 이후 값으로 채움 (bfill 대신 bfill() 사용)
df['value'] = df['value'].bfill()
print(df)
# Out:
#             value
# 2022-01-01    1.0
# 2022-01-02    2.0
# 2022-01-03    3.0
# 2022-01-04    4.0
# 2022-01-05    5.0
#             value
# 2022-01-01    1.0
# 2022-01-02    2.0
# 2022-01-03    3.0
# 2022-01-04    4.0
# 2022-01-05    5.0

# %%
#이상치 : 일반적인 데이터 집합에서 벗어난다. 값이 존재하지 않을 때 사용하는 값 
# Null,None,Na,NaN 등으로 표기

# %%
import missingno as msno #데이터프레임 결측값을 탐색하는 라이브러리 
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('bike_sharing_daily.csv')

# %%
df.isna().sum() 
#결측치 없음
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df.dropna(how='any')
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
#데이터 출력할 때 결측치만 출력을 원한다 -> loc[결측치에 해당하는 컬럼 key를 지정하면 된다.]
df.loc[df['temp'].isna()]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
df.loc[~df['temp'].isna()]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df.loc[:2].fillna(0)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
#
#     cnt
# 0   985
# 1   801
# 2  1349

# %%
df.loc[:2].fillna('na값!')
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
#
#     cnt
# 0   985
# 1   801
# 2  1349

# %%
display(df.loc[:5])
display(df.loc[:5].fillna(method='bfill'))
display(df.loc[:5].fillna(method='ffill'))
display(df.loc[:5].interpolate())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
# 5        6  06-01-2018       1   0     1        0        4           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
# ...
